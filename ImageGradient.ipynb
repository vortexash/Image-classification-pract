# %% [markdown]
# <a href="https://colab.research.google.com/github/vortexash/Image-classification-pract/blob/master/ImageGradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import data,color

# %%
image=color.rgb2gray(data.chelsea())

# %%
gx=np.empty(image.shape,dtype=np.double)

# %%
#####Horizontal gradient
gx[:,0]=0
gx[:,-1]=0
gx[:,1:-1]=image[:,:-2] - image[:,2:]

# %%
#### Vertical gradient
gy=np.empty(image.shape,dtype=np.double)
gy[0,:]=0
gy[-1,:]=0
gy[1:-1,:]=image[:-2,:] - image[2:,:]

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,1,figsize=(5,9),sharex=True,sharey=True)
ax1.axis('off')
ax1.imshow(image,cmap=plt.cm.gray)
ax1.set_title("Original Image")
ax1.set_adjustable('box-forced')

ax2.axis('off')
ax2.imshow(gx,cmap=plt.cm.gray)
ax2.set_title("Horizontal gradient")
ax2.set_adjustable('box-forced')


ax3.axis('off')
ax3.imshow(gy,cmap=plt.cm.gray)
ax3.set_title("Vertical gradient")
ax3.set_adjustable('box-forced')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:1334: MatplotlibDeprecationWarning:
# box-forced
#   "2.2", "box-forced", obj_type="keyword argument")
